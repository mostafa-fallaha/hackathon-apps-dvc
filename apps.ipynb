# %%
import pandas as pd
import numpy as np
import re
import subprocess
from pathlib import Path 
import io
import dvc.api, dvc.repo

# %% [markdown]
# # Google play store

# %%
url = "https://github.com/mostafa-fallaha/hackathon-apps-dvc"
data = dvc.api.read("data/googleplaystore.csv", encoding='utf-8', repo=url)
df = pd.read_csv(io.StringIO(data))
df.sample(10)
# Out:
#                                                   App             Category  \
# 1834                                    The Escapists                 GAME
# 6460                                         Myjob@BM               SOCIAL
# 5216                   Turbo AI™ - Personal assistant         PRODUCTIVITY
# 1031   Picktrainer: India's largest photo contest app               EVENTS
# 4453                           [substratum] Vacuum: P      PERSONALIZATION
# 10479                              Free Wi-fi HotspoT        COMMUNICATION
# 2905            Camera MX - Free Photo & Video Camera          PHOTOGRAPHY
# 38                     PIP Camera - PIP Collage Maker       ART_AND_DESIGN
# 10268                       Middlesbrough FC Official               SPORTS
# 174                  English translation from Bengali  BOOKS_AND_REFERENCE
#
#        Rating Reviews                Size     Installs  Type  Price  \
# 1834      4.4    7412                 84M     100,000+  Paid  $4.99
# 6460      NaN       1  Varies with device         100+  Free      0
# 5216      2.6      91                2.8M       5,000+  Free      0
# 1031      4.5    1065                9.0M     100,000+  Free      0
# 4453      4.4     230                 11M       1,000+  Paid  $1.49
# 10479     4.1     382                2.3M      50,000+  Free      0
# 2905      4.3  244371  Varies with device  10,000,000+  Free      0
# 38        4.7     158                 11M      10,000+  Free      0
# 10268     4.5     152                 36M      10,000+  Free      0
# 174       4.5     527                2.9M     100,000+  Free      0
#
#       Content Rating             Genres       Last Updated  \
# 1834            Teen           Strategy     April 26, 2018
# 6460            Teen             Social      June 13, 2018
# 5216        Everyone       Productivity      July 16, 2018
# 1031        Everyone             Events       May 31, 2018
# 4453        Everyone    Personalization      July 20, 2018
# 10479       Everyone      Communication      July 20, 2018
# 2905        Everyone        Photography       July 5, 2018
# 38          Everyone       Art & Design  November 29, 2017
# 10268       Everyone             Sports       May 29, 2018
# 174         Everyone  Books & Reference     March 31, 2018
#
#               Current Ver         Android Ver
# 1834                1.1.0          2.3 and up
# 6460              1.16.21          4.1 and up
# 5216               0.0.52        4.0.3 and up
# 1031                1.3.2          4.1 and up
# 4453                  4.4                 NaN
# 10479                 2.5          4.0 and up
# 2905   Varies with device  Varies with device
# 38                    1.3        4.0.3 and up
# 10268           2018.5.25          4.4 and up
# 174                  14.0          4.0 and up

# %%
df.shape
# Out:
# (10841, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %% [markdown]
# ## Cleaning

# %% [markdown]
# ### fixing to the left - Rating

# %%
df.loc[df['Rating'] == df['Rating'].max()]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
cols = df.columns.to_list()
cols.pop(0)
cols
# Out:
# ['Category',
#  'Rating',
#  'Reviews',
#  'Size',
#  'Installs',
#  'Type',
#  'Price',
#  'Content Rating',
#  'Genres',
#  'Last Updated',
#  'Current Ver',
#  'Android Ver']

# %%
for i in range(len(cols)-1, 0, -1):
    print(cols[i])
    if cols[i] == 'Rating':
        df.loc[10472, cols[i]] = float(df.loc[10472, cols[i-1]])
    else:
        df.loc[10472, cols[i]] = df.loc[10472, cols[i-1]]
# Out:
# Android Ver
# Current Ver
# Last Updated
# Genres
# Content Rating
# Price
# Type
# Installs
# Size
# Reviews
# Rating

# %%
df.loc[[10472]]
# Out:
#                                            App Category  Rating Reviews  Size  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9     1.9    19.0  3.0M
#
#       Installs  Type Price Content Rating Genres       Last Updated  \
# 10472   1,000+  Free     0       Everyone    NaN  February 11, 2018
#
#       Current Ver Android Ver
# 10472      1.0.19  4.0 and up

# %%
df.loc[10472, 'Category'] = 'LIFESTYLE'
df.loc[10472, 'Genres'] = 'LIFESTYLE'

# %%
df.loc[[10472]]
# Out:
#                                            App   Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame  LIFESTYLE     1.9    19.0
#
#        Size Installs  Type Price Content Rating     Genres       Last Updated  \
# 10472  3.0M   1,000+  Free     0       Everyone  LIFESTYLE  February 11, 2018
#
#       Current Ver Android Ver
# 10472      1.0.19  4.0 and up

# %%
df.fillna({'Rating': df['Rating'].mean()}, inplace=True)

# %% [markdown]
# ### Type

# %%
df.loc[df['Type'].isna()]
# Out:
#                             App Category    Rating Reviews  \
# 9148  Command & Conquer: Rivals   FAMILY  4.191513       0
#
#                     Size Installs Type Price Content Rating    Genres  \
# 9148  Varies with device        0  NaN     0   Everyone 10+  Strategy
#
#        Last Updated         Current Ver         Android Ver
# 9148  June 28, 2018  Varies with device  Varies with device

# %%
df.loc[df['Type'] == 'Free'].shape
# Out:
# (10040, 13)

# %%
df.loc[df['Type'] == 'Paid'].shape
# Out:
# (800, 13)

# %%
df.fillna({'Type':'Free'}, inplace=True)

# %%
df.loc[df['Type'].isna()]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
df.loc[df['Type'] == 'Free'].shape
# Out:
# (10041, 13)

# %%
df[df['Size'].str.endswith('G')]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %% [markdown]
# ### Installs

# %%
# Step 1: Remove non-numeric characters (commas and plus sign)
df['Installs'] = df['Installs'].replace('[\+,]', '', regex=True)
# Step 2: Convert the resulting string to an integer
df['Installs'] = df['Installs'].astype(int)
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size  Installs  Type Price Content Rating  \
# 0     159   19M     10000  Free     0       Everyone
# 1     967   14M    500000  Free     0       Everyone
# 2   87510  8.7M   5000000  Free     0       Everyone
# 3  215644   25M  50000000  Free     0           Teen
# 4     967  2.8M    100000  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %% [markdown]
# ### Last Updated

# %%
df['Last Updated'] = pd.to_datetime(df['Last Updated'])

# %%
df.iloc[[5583]]
# Out:
#                             App Category  Rating Reviews  Size  Installs  \
# 5583  The Aether: Life as a God   FAMILY     4.1    1407  3.4M    100000
#
#       Type Price Content Rating        Genres Last Updated Current Ver  \
# 5583  Free     0   Everyone 10+  Role Playing   2018-03-12       1.0.5
#
#      Android Ver
# 5583  4.0 and up

# %% [markdown]
# ### Reviews

# %%
df['Reviews'] = df['Reviews'].astype(int)

# %% [markdown]
# ### Price

# %%
def clean_price(price):
    # Ensure the price is a string
    if isinstance(price, str):
        # Remove any non-numeric characters, except for the dot
        cleaned_price = price.replace('$', '').replace('£', '').replace(',', '')
        try:
            # Convert to float
            return float(cleaned_price)
        except ValueError:
            return None
    return price

# %%
df['Price'] = df['Price'].apply(clean_price)

# %% [markdown]
# ### Fixing the size

# %%
df[df['Size'].str.endswith('k')].head(2)
# Out:
#                    App           Category  Rating  Reviews  Size  Installs  \
# 58   Restart Navigator  AUTO_AND_VEHICLES     4.0     1403  201k    100000
# 209    Plugin:AOT v5.0           BUSINESS     3.1     4034   23k    100000
#
#      Type  Price Content Rating           Genres Last Updated  \
# 58   Free    0.0       Everyone  Auto & Vehicles   2014-08-26
# 209  Free    0.0       Everyone         Business   2015-09-11
#
#               Current Ver Android Ver
# 58                  1.0.1  2.2 and up
# 209  3.0.1.11 (Build 311)  2.2 and up

# %%
def convert_to_megabytes(size):
  """Converts a size string from KB to MB"""
  if size.endswith('k'):
    # Remove the 'K' and convert to float
    size_in_kb = float(size[:-1])
    # Convert to MB by dividing by 1024
    size_in_mb = size_in_kb / 1024
    return f"{size_in_mb:.2f}M"  # Format to 2 decimal places and add 'M'
  else:
    return size

df['Size'] = df['Size'].apply(convert_to_megabytes)

# %%
df.iloc[[58]]
# Out:
#                   App           Category  Rating  Reviews   Size  Installs  \
# 58  Restart Navigator  AUTO_AND_VEHICLES     4.0     1403  0.20M    100000
#
#     Type  Price Content Rating           Genres Last Updated Current Ver  \
# 58  Free    0.0       Everyone  Auto & Vehicles   2014-08-26       1.0.1
#
#    Android Ver
# 58  2.2 and up

# %%
df['Size'].value_counts()
# Out:
# Size
# Varies with device    1695
# 11M                    198
# 12M                    196
# 14M                    194
# 13M                    191
#                       ...
# 0.44M                    1
# 0.10M                    1
# 0.75M                    1
# 0.48M                    1
# 1.00M                    1
# Name: count, Length: 276, dtype: int64

# %%
df.sample(7)
# Out:
#                                                    App             Category  \
# 4740                              Dictionary - WordWeb  BOOKS_AND_REFERENCE
# 1929                                    Kick the Buddy                 GAME
# 4943                     Ad Detect Plugin - Handy Tool         PRODUCTIVITY
# 4568   360 Security - Free Antivirus, Booster, Cleaner                TOOLS
# 2821                                         HD Camera          PHOTOGRAPHY
# 4330                                             EXO-L               FAMILY
# 4322  letgo: Buy & Sell Used Stuff, Cars & Real Estate             SHOPPING
#
#       Rating   Reviews                Size   Installs  Type  Price  \
# 4740     4.6    124970  Varies with device    5000000  Free    0.0
# 1929     4.3   1003269  Varies with device   50000000  Free    0.0
# 4943     3.8      5107                1.4M     500000  Free    0.0
# 4568     4.6  16771865  Varies with device  100000000  Free    0.0
# 2821     4.3     49680                8.7M    5000000  Free    0.0
# 4330     4.6     67410               0.84M    1000000  Free    0.0
# 4322     4.5    972256                 20M   50000000  Free    0.0
#
#      Content Rating             Genres Last Updated         Current Ver  \
# 4740           Teen  Books & Reference   2018-05-26  Varies with device
# 1929           Teen             Action   2018-07-05  Varies with device
# 4943       Everyone       Productivity   2015-12-28               1.6.3
# 4568       Everyone              Tools   2018-08-04  Varies with device
# 2821       Everyone        Photography   2018-07-11               1.8.5
# 4330       Everyone      Entertainment   2017-11-02               1.0.9
# 4322           Teen           Shopping   2018-08-02               2.4.8
#
#              Android Ver
# 4740  Varies with device
# 1929          4.4 and up
# 4943          2.3 and up
# 4568  Varies with device
# 2821          4.2 and up
# 4330          2.2 and up
# 4322          4.1 and up

# %%
# def convert_size(size):
#     if 'M' in size:
#         return float(size.replace('M', ''))
#     elif 'k' in size:
#         return float(size.replace('k', '')) / 1024
#     return np.nan
# df['Size_num'] = df['Size'].apply(lambda x: convert_size(x) if x != 'Varies with device' else np.nan)
# # Calculate average size per category
# df_sorted = df.sort_values(by='Size_num', ascending=False)
# top_5_per_category = df_sorted.groupby('Category').head(3)
# category_avg_size = top_5_per_category.groupby('Category')['Size_num'].mean().round(1)
# print(category_avg_size)
# # Replace 'Varies with device' with the average size of the category
# df['Size_num'] = df.apply(
#     lambda row: category_avg_size[row['Category']] if pd.isna(row['Size_num']) else row['Size_num'],
#     axis=1
# )

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size  Installs  Type  Price Content Rating  \
# 0      159   19M     10000  Free    0.0       Everyone
# 1      967   14M    500000  Free    0.0       Everyone
# 2    87510  8.7M   5000000  Free    0.0       Everyone
# 3   215644   25M  50000000  Free    0.0           Teen
# 4      967  2.8M    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver
# 0               Art & Design   2018-01-07               1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play   2018-01-15               2.0.0  4.0.3 and up
# 2               Art & Design   2018-08-01               1.2.4  4.0.3 and up
# 3               Art & Design   2018-06-08  Varies with device    4.2 and up
# 4    Art & Design;Creativity   2018-06-20                 1.1    4.4 and up

# %%
# # Convert the numeric size back to string with 'M' for display purposes
# df['Size'] = df['Size_num'].apply(lambda x: f"{x:.1f}M")
# # Drop the helper column
# df.drop(columns=['Size_num'], inplace=True)

# %%
df.iloc[[139]]
# Out:
#                       App             Category  Rating  Reviews  \
# 139  Wattpad 📖 Free Books  BOOKS_AND_REFERENCE     4.6  2914724
#
#                    Size   Installs  Type  Price Content Rating  \
# 139  Varies with device  100000000  Free    0.0           Teen
#
#                 Genres Last Updated         Current Ver         Android Ver
# 139  Books & Reference   2018-08-01  Varies with device  Varies with device

# %%
# df.loc[df['Size'] == 'Varies with device']

# %%
df.loc[df['Size'] == 'Varies with device'].shape[0]
# Out:
# 1695

# %%
# def convert_size_to_float(size):
#     if 'M' in size:
#         return float(size.replace('M', ''))
# df['Size'] = df['Size'].apply(convert_size_to_float)

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size  Installs  Type  Price Content Rating  \
# 0      159   19M     10000  Free    0.0       Everyone
# 1      967   14M    500000  Free    0.0       Everyone
# 2    87510  8.7M   5000000  Free    0.0       Everyone
# 3   215644   25M  50000000  Free    0.0           Teen
# 4      967  2.8M    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver
# 0               Art & Design   2018-01-07               1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play   2018-01-15               2.0.0  4.0.3 and up
# 2               Art & Design   2018-08-01               1.2.4  4.0.3 and up
# 3               Art & Design   2018-06-08  Varies with device    4.2 and up
# 4    Art & Design;Creativity   2018-06-20                 1.1    4.4 and up

# %% [markdown]
# ### Content Rating

# %%
df['Content Rating'].value_counts()
# Out:
# Content Rating
# Everyone           8715
# Teen               1208
# Mature 17+          499
# Everyone 10+        414
# Adults only 18+       3
# Unrated               2
# Name: count, dtype: int64

# %%
df.loc[df['Content Rating'] == 'Unrated']
# Out:
#                          App Category    Rating  Reviews  Size  Installs  \
# 7312     Best CG Photography   FAMILY  4.191513        1  2.5M       500
# 8266  DC Universe Online Map    TOOLS  4.100000     1186  6.4M     50000
#
#       Type  Price Content Rating         Genres Last Updated Current Ver  \
# 7312  Free    0.0        Unrated  Entertainment   2015-06-24         5.2
# 8266  Free    0.0        Unrated          Tools   2012-02-27         1.3
#
#        Android Ver
# 7312    3.0 and up
# 8266  2.3.3 and up

# %% [markdown]
# ### Current Version

# %%
df.loc[df['Current Ver'].isna()]
# Out:
#                                    App             Category    Rating  \
# 15     Learn To Draw Kawaii Characters       ART_AND_DESIGN  3.200000
# 1553              Market Update Helper   LIBRARIES_AND_DEMO  4.100000
# 6322            Virtual DJ Sound Mixer                TOOLS  4.200000
# 6803                         BT Master               FAMILY  4.191513
# 7333                       Dots puzzle               FAMILY  4.000000
# 7407                   Calculate My IQ               FAMILY  4.191513
# 7730                            UFO-CQ                TOOLS  4.191513
# 10342                   La Fe de Jesus  BOOKS_AND_REFERENCE  4.191513
#
#        Reviews   Size  Installs  Type  Price Content Rating  \
# 15          55   2.7M      5000  Free   0.00       Everyone
# 1553     20145  0.01M   1000000  Free   0.00       Everyone
# 6322      4010   8.7M    500000  Free   0.00       Everyone
# 6803         0  0.22M       100  Free   0.00       Everyone
# 7333       179    14M     50000  Paid   0.99       Everyone
# 7407        44   7.2M     10000  Free   0.00       Everyone
# 7730         1  0.23M        10  Paid   0.99       Everyone
# 10342        8  0.64M      1000  Free   0.00       Everyone
#
#                   Genres Last Updated Current Ver Android Ver
# 15          Art & Design   2018-06-06         NaN  4.2 and up
# 1553    Libraries & Demo   2013-02-12         NaN  1.5 and up
# 6322               Tools   2017-05-10         NaN  4.0 and up
# 6803           Education   2016-11-06         NaN  1.6 and up
# 7333              Puzzle   2018-04-18         NaN  4.0 and up
# 7407       Entertainment   2017-04-03         NaN  2.3 and up
# 7730               Tools   2016-07-04         NaN  2.0 and up
# 10342  Books & Reference   2017-01-31         NaN  3.0 and up

# %%
df.fillna({'Current Ver':'1.0.0.0'}, inplace=True)

# %%
df.iloc[[15, 1553]]
# Out:
#                                   App            Category  Rating  Reviews  \
# 15    Learn To Draw Kawaii Characters      ART_AND_DESIGN     3.2       55
# 1553             Market Update Helper  LIBRARIES_AND_DEMO     4.1    20145
#
#        Size  Installs  Type  Price Content Rating            Genres  \
# 15     2.7M      5000  Free    0.0       Everyone      Art & Design
# 1553  0.01M   1000000  Free    0.0       Everyone  Libraries & Demo
#
#      Last Updated Current Ver Android Ver
# 15     2018-06-06     1.0.0.0  4.2 and up
# 1553   2013-02-12     1.0.0.0  1.5 and up

# %%
df['Current Ver'].isna().sum()
# Out:
# 0

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size  Installs  Type  Price Content Rating  \
# 0      159   19M     10000  Free    0.0       Everyone
# 1      967   14M    500000  Free    0.0       Everyone
# 2    87510  8.7M   5000000  Free    0.0       Everyone
# 3   215644   25M  50000000  Free    0.0           Teen
# 4      967  2.8M    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver
# 0               Art & Design   2018-01-07               1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play   2018-01-15               2.0.0  4.0.3 and up
# 2               Art & Design   2018-08-01               1.2.4  4.0.3 and up
# 3               Art & Design   2018-06-08  Varies with device    4.2 and up
# 4    Art & Design;Creativity   2018-06-20                 1.1    4.4 and up

# %%
# Calculate the most common version per category
# most_common_version = df[df['Current Ver'] != 'Varies with device'].groupby('Category')['Current Ver'].agg(lambda x: x.mode()[0])
# # Replace 'Varies with device' with the most common version for the category
# df['Current Ver'] = df.apply(
#  lambda row: most_common_version[row['Category']] if row['Current Ver'] == 'Varies with device' else row['Current Ver'],
#  axis=1
# )

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size  Installs  Type  Price Content Rating  \
# 0      159   19M     10000  Free    0.0       Everyone
# 1      967   14M    500000  Free    0.0       Everyone
# 2    87510  8.7M   5000000  Free    0.0       Everyone
# 3   215644   25M  50000000  Free    0.0           Teen
# 4      967  2.8M    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver
# 0               Art & Design   2018-01-07               1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play   2018-01-15               2.0.0  4.0.3 and up
# 2               Art & Design   2018-08-01               1.2.4  4.0.3 and up
# 3               Art & Design   2018-06-08  Varies with device    4.2 and up
# 4    Art & Design;Creativity   2018-06-20                 1.1    4.4 and up

# %% [markdown]
# ### Android Ver

# %%
df.loc[df['Android Ver'].isna()]
# Out:
#                          App         Category  Rating  Reviews  Size  \
# 4453  [substratum] Vacuum: P  PERSONALIZATION     4.4      230   11M
# 4490    Pi Dark [substratum]  PERSONALIZATION     4.5      189  2.1M
#
#       Installs  Type  Price Content Rating           Genres Last Updated  \
# 4453      1000  Paid   1.49       Everyone  Personalization   2018-07-20
# 4490     10000  Free   0.00       Everyone  Personalization   2018-03-27
#
#      Current Ver Android Ver
# 4453         4.4         NaN
# 4490         1.1         NaN

# %%
df.fillna({'Android Ver': '3.0 and up'}, inplace=True)

# %%
df['Android Ver'].isna().sum()
# Out:
# 0

# %%
def extract_float(value):
    match = re.search(r'\d+\.\d+', value)
    return float(match.group(0)) if match else value

# %%
df['Android Ver'] = df['Android Ver'].apply(extract_float)

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size  Installs  Type  Price Content Rating  \
# 0      159   19M     10000  Free    0.0       Everyone
# 1      967   14M    500000  Free    0.0       Everyone
# 2    87510  8.7M   5000000  Free    0.0       Everyone
# 3   215644   25M  50000000  Free    0.0           Teen
# 4      967  2.8M    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver Android Ver
# 0               Art & Design   2018-01-07               1.0.0         4.0
# 1  Art & Design;Pretend Play   2018-01-15               2.0.0         4.0
# 2               Art & Design   2018-08-01               1.2.4         4.0
# 3               Art & Design   2018-06-08  Varies with device         4.2
# 4    Art & Design;Creativity   2018-06-20                 1.1         4.4

# %%
df.loc[df['Android Ver'] == 'Varies with device']
# Out:
#                                                      App             Category  \
# 42                            Textgram - write on photos       ART_AND_DESIGN
# 52                         Used Cars and Trucks for Sale    AUTO_AND_VEHICLES
# 67                                    Ulysse Speedometer    AUTO_AND_VEHICLES
# 68                                                REPUVE    AUTO_AND_VEHICLES
# 85     CarMax – Cars for Sale: Search Used Car Inventory    AUTO_AND_VEHICLES
# ...                                                  ...                  ...
# 10713  My Earthquake Alerts - US & Worldwide Earthquakes              WEATHER
# 10765                    Chat For Strangers - Video Chat               SOCIAL
# 10826          Frim: get new friends on local chat rooms               SOCIAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating  Reviews                Size  Installs  Type  Price  \
# 42        4.4   295221  Varies with device  10000000  Free    0.0
# 52        4.6    17057  Varies with device   1000000  Free    0.0
# 67        4.3    40211  Varies with device   5000000  Free    0.0
# 68        3.9      356  Varies with device    100000  Free    0.0
# 85        4.4    21777  Varies with device   1000000  Free    0.0
# ...       ...      ...                 ...       ...   ...    ...
# 10713     4.4     3471  Varies with device    100000  Free    0.0
# 10765     3.4      622  Varies with device    100000  Free    0.0
# 10826     4.0    88486  Varies with device   5000000  Free    0.0
# 10839     4.5      114  Varies with device      1000  Free    0.0
# 10840     4.5   398307                 19M  10000000  Free    0.0
#
#       Content Rating             Genres Last Updated         Current Ver  \
# 42          Everyone       Art & Design   2018-07-30  Varies with device
# 52          Everyone    Auto & Vehicles   2018-07-30  Varies with device
# 67          Everyone    Auto & Vehicles   2018-07-30  Varies with device
# 68          Everyone    Auto & Vehicles   2018-05-25  Varies with device
# 85          Everyone    Auto & Vehicles   2018-08-04  Varies with device
# ...              ...                ...          ...                 ...
# 10713       Everyone            Weather   2018-07-24  Varies with device
# 10765     Mature 17+             Social   2018-05-23  Varies with device
# 10826     Mature 17+             Social   2018-03-23  Varies with device
# 10839     Mature 17+  Books & Reference   2015-01-19  Varies with device
# 10840       Everyone          Lifestyle   2018-07-25  Varies with device
#
#               Android Ver
# 42     Varies with device
# 52     Varies with device
# 67     Varies with device
# 68     Varies with device
# 85     Varies with device
# ...                   ...
# 10713  Varies with device
# 10765  Varies with device
# 10826  Varies with device
# 10839  Varies with device
# 10840  Varies with device
#
# [1362 rows x 13 columns]

# %%
df.iloc[[139]]
# Out:
#                       App             Category  Rating  Reviews  \
# 139  Wattpad 📖 Free Books  BOOKS_AND_REFERENCE     4.6  2914724
#
#                    Size   Installs  Type  Price Content Rating  \
# 139  Varies with device  100000000  Free    0.0           Teen
#
#                 Genres Last Updated         Current Ver         Android Ver
# 139  Books & Reference   2018-08-01  Varies with device  Varies with device

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          10841 non-null  float64
#  3   Reviews         10841 non-null  int32
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  int32
#  6   Type            10841 non-null  object
#  7   Price           10841 non-null  float64
#  8   Content Rating  10841 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  datetime64[ns]
#  11  Current Ver     10841 non-null  object
#  12  Android Ver     10841 non-null  object
# dtypes: datetime64[ns](1), float64(2), int32(2), object(8)
# memory usage: 1016.5+ KB

# %%
filepath = Path('data/googleplaystore.csv')
filepath.parent.mkdir(parents=True, exist_ok=True)
df.to_csv(filepath, index=False)

# %% [markdown]
# # Commits

# %%
commit_message = "cleaned the data for backend"

subprocess.run(["powershell", "-File", "run_versioning_apps.ps1", commit_message], check=True)
# Out:
# CompletedProcess(args=['powershell', '-File', 'run_versioning_apps.ps1', 'cleaned the data for backend'], returncode=0)
